# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 0                    Global              NaN                 122992844
# 1  United States of America         Americas                  29497998
# 2                    Brazil         Americas                  11950459
# 3                     India  South-East Asia                  11646081
# 4        Russian Federation           Europe                   4466153
#
#    Cases - cumulative total per 100000 population  \
# 0                                     1575.556615
# 1                                     8911.710000
# 2                                     5622.170000
# 3                                      843.920000
# 4                                     3060.380000
#
#    Cases - newly reported in last 7 days  \
# 0                                3345604
# 1                                 382336
# 2                                 510901
# 3                                 260742
# ...

# %%
print(df['Cases - cumulative total'].dtype)
# Out:
# int64

# %%
print(df['Cases - cumulative total'].astype("category"))
# Out:
# 0      122992844
# 1       29497998
# 2       11950459
# 3       11646081
# 4        4466153
#          ...
# 232            0
# 233            0
# 234            0
# 235            0
# 236            0
# Name: Cases - cumulative total, Length: 237, dtype: category
# Categories (221, int64): [0, 3, 4, 6, ..., 11646081, 11950459, 29497998, 122992844]
