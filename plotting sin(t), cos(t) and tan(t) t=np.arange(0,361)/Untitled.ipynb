# %%
import pandas as pd
import numpy as np

from decimal import Decimal as d
from matplotlib import pyplot as plt
my_arr= np.radians(np.arange(0,361))

# %%
df = pd.DataFrame({
    "sin":np.array(np.sin(np.deg2rad(np.arange(0,361)))),
    "cos":np.array(np.cos(np.deg2rad(np.arange(0,361)))),
    "tan":np.array(np.tan(np.deg2rad(np.arange(0,361)))),
}, index=np.arange(0, 361))

# %%
df
# Out:
#               sin       cos           tan
# 0    0.000000e+00  1.000000  0.000000e+00
# 1    1.745241e-02  0.999848  1.745506e-02
# 2    3.489950e-02  0.999391  3.492077e-02
# 3    5.233596e-02  0.998630  5.240778e-02
# 4    6.975647e-02  0.997564  6.992681e-02
# ..            ...       ...           ...
# 356 -6.975647e-02  0.997564 -6.992681e-02
# 357 -5.233596e-02  0.998630 -5.240778e-02
# 358 -3.489950e-02  0.999391 -3.492077e-02
# 359 -1.745241e-02  0.999848 -1.745506e-02
# 360 -2.449294e-16  1.000000 -2.449294e-16
#
# [361 rows x 3 columns]

# %%
df.loc[90, "cos"]
df.loc[:, "sin"]
# Out:
# 0      0.000000e+00
# 1      1.745241e-02
# 2      3.489950e-02
# 3      5.233596e-02
# 4      6.975647e-02
#            ...
# 356   -6.975647e-02
# 357   -5.233596e-02
# 358   -3.489950e-02
# 359   -1.745241e-02
# 360   -2.449294e-16
# Name: sin, Length: 361, dtype: float64

# %%
np.array(np.cos(np.deg2rad(90)))
# Out:
# array(6.123234e-17)

# %%
plt.plot(my_arr, df.loc[:, "sin"]) #in radians
plt.plot(my_arr, df.loc[:, "cos"]) #in radians

# %%
plt.plot(my_arr, df.loc[:, "cos"]) #in radians

# %%
plt.plot(my_arr, df.loc[:, "tan"]) #in radians

# %%
plt.show()

# %%
plt.plot(df.index, df.loc[:,"sin"]) #in degrees
plt.plot(df.index, df.loc[:, 'cos']) #in degrees

# %%
my_arr
# Out:
# array([0.        , 0.01745329, 0.03490659, 0.05235988, 0.06981317,
#        0.08726646, 0.10471976, 0.12217305, 0.13962634, 0.15707963,
#        0.17453293, 0.19198622, 0.20943951, 0.2268928 , 0.2443461 ,
#        0.26179939, 0.27925268, 0.29670597, 0.31415927, 0.33161256,
#        0.34906585, 0.36651914, 0.38397244, 0.40142573, 0.41887902,
#        0.43633231, 0.45378561, 0.4712389 , 0.48869219, 0.50614548,
#        0.52359878, 0.54105207, 0.55850536, 0.57595865, 0.59341195,
#        0.61086524, 0.62831853, 0.64577182, 0.66322512, 0.68067841,
#        0.6981317 , 0.71558499, 0.73303829, 0.75049158, 0.76794487,
#        0.78539816, 0.80285146, 0.82030475, 0.83775804, 0.85521133,
#        0.87266463, 0.89011792, 0.90757121, 0.9250245 , 0.9424778 ,
#        0.95993109, 0.97738438, 0.99483767, 1.01229097, 1.02974426,
#        1.04719755, 1.06465084, 1.08210414, 1.09955743, 1.11701072,
#        1.13446401, 1.15191731, 1.1693706 , 1.18682389, 1.20427718,
# ...
