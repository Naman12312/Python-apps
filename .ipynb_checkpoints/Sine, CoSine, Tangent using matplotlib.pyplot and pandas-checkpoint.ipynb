# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.plot(np.arange(0, 20), np.sin(np.arange(0,20)))

# %%
plt.plot(np.arange(0, 361), np.sin(np.radians(np.arange(0,361))))
plt.plot(np.arange(0,361), np.cos(np.radians(np.arange(0,361))))

# %%
plt.show()

# %%
plt.plot(np.arange(0,361), np.tan(np.arange(0,361)))

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "name":["GoldarmGang","NamaN SharmA", "Opboy64", "namanthetoxic"],
    "roll no":[1,2,3,4],
    "0 or 1":[1,1,1,1]
})

# %%
df
# Out:
#             name  roll no  0 or 1
# 0    GoldarmGang        1       1
# 1   NamaN SharmA        2       1
# 2        Opboy64        3       1
# 3  namanthetoxic        4       1

# %%
df.loc[-1, 0] = np.nan

# %%
df = df.drop(-1, axis=0)
df = df.drop(0, axis=1)

# %%
df
# Out:
#             name  roll no  0 or 1
# 0    GoldarmGang      1.0     1.0
# 1   NamaN SharmA      2.0     1.0
# 2        Opboy64      3.0     1.0
# 3  namanthetoxic      4.0     1.0

# %%
df.loc[0, -1] = np.nan

# %%
df.loc[0,-1] = "-1"

# %%
df
# Out:
#             name  roll no  0 or 1   -1
# 0    GoldarmGang      1.0     1.0   -1
# 1   NamaN SharmA      2.0     1.0  NaN
# 2        Opboy64      3.0     1.0  NaN
# 3  namanthetoxic      4.0     1.0  NaN

# %%
df
# Out:
#             name  roll no  0 or 1   -1
# 0    GoldarmGang      1.0     1.0   -1
# 1   NamaN SharmA      2.0     1.0  NaN
# 2        Opboy64      3.0     1.0  NaN
# 3  namanthetoxic      4.0     1.0  NaN

# %%
df.describe()
# Out:
#         roll no  0 or 1
# count  4.000000     4.0
# mean   2.500000     1.0
# std    1.290994     0.0
# min    1.000000     1.0
# 25%    1.750000     1.0
# 50%    2.500000     1.0
# 75%    3.250000     1.0
# max    4.000000     1.0

# %%
df.head()
# Out:
#             name  roll no  0 or 1   -1
# 0    GoldarmGang      1.0     1.0   -1
# 1   NamaN SharmA      2.0     1.0  NaN
# 2        Opboy64      3.0     1.0  NaN
# 3  namanthetoxic      4.0     1.0  NaN

# %%
df.tail()
# Out:
#             name  roll no  0 or 1   -1
# 0    GoldarmGang      1.0     1.0   -1
# 1   NamaN SharmA      2.0     1.0  NaN
# 2        Opboy64      3.0     1.0  NaN
# 3  namanthetoxic      4.0     1.0  NaN

# %%
new_df = pd.DataFrame({
    "angle":np.arange(0, 361),
    "sine":np.sin(np.radians(np.arange(0,361))),
    "cosine":np.cos(np.radians(np.arange(0,361))),
    "tangent":np.tan(np.radians(np.arange(0,361)))
})

# %%
new_df
# Out:
#      angle          sine    cosine       tangent
# 0        0  0.000000e+00  1.000000  0.000000e+00
# 1        1  1.745241e-02  0.999848  1.745506e-02
# 2        2  3.489950e-02  0.999391  3.492077e-02
# 3        3  5.233596e-02  0.998630  5.240778e-02
# 4        4  6.975647e-02  0.997564  6.992681e-02
# ..     ...           ...       ...           ...
# 356    356 -6.975647e-02  0.997564 -6.992681e-02
# 357    357 -5.233596e-02  0.998630 -5.240778e-02
# 358    358 -3.489950e-02  0.999391 -3.492077e-02
# 359    359 -1.745241e-02  0.999848 -1.745506e-02
# 360    360 -2.449294e-16  1.000000 -2.449294e-16
#
# [361 rows x 4 columns]

# %%
new_df.loc[100, "tangent"]
# Out:
# -5.671281819617711

# %%
new_df = new_df.drop("tangent", axis=1)

# %%
new_df
df = pd.DataFrame({
    "basic graph x":np.array([0.1, 0.5, 1, 2, 5, 10]),
    "basic graph y":np.array([100, 20, 10, 5, 2, 1])
})
df.columns = ["x","y"]
df
plt.plot(df.loc[:,"x"], df.loc[:, "y"])

# %%
plt.plot(new_df.loc[:,"angle"], new_df.loc[:, "sine"])
plt.plot(new_df.loc[:,"angle"], new_df.loc[:, "cosine"])

plt.show()

# %%
new_df.loc[np.arange(0, np.array(new_df.index).shape[0]), "sine"]
# Out:
# 0      0.000000e+00
# 1      1.745241e-02
# 2      3.489950e-02
# 3      5.233596e-02
# 4      6.975647e-02
#            ...
# 356   -6.975647e-02
# 357   -5.233596e-02
# 358   -3.489950e-02
# 359   -1.745241e-02
# 360   -2.449294e-16
# Name: sine, Length: 361, dtype: float64

# %%
new_df.loc[:, "sine"]
# Out:
# 0      0.000000e+00
# 1      1.745241e-02
# 2      3.489950e-02
# 3      5.233596e-02
# 4      6.975647e-02
#            ...
# 356   -6.975647e-02
# 357   -5.233596e-02
# 358   -3.489950e-02
# 359   -1.745241e-02
# 360   -2.449294e-16
# Name: sine, Length: 361, dtype: float64

# %%
column_data = new_df.loc[:, 'sine']
