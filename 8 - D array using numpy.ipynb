# %%
import numpy as np

# %%
arr0 = np.int64(9_223_372_036_854_775_807)

# %%
arr0
# Out:
# 9223372036854775807

# %%
arr1 = np.array([1,2,3,4,5])

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr2 = np.array([[1,2,3,4,5],
         [13,4,562,2,3]])

# %%
arr2
# Out:
# array([[  1,   2,   3,   4,   5],
#        [ 13,   4, 562,   2,   3]])

# %%
arr2.ndim
# Out:
# 2

# %%
arr3 = np.array([
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


])

# %%
arr3.shape
# Out:
# (3, 3, 7)

# %%
arr3
# Out:
# array([[[   1,    2,    5,    6,    3,    6,    2],
#         [   2, 5455,    6,    7,    2,    8,    8],
#         [   1,    2,    3,    4,    5,    6,    7]],
#
#        [[   1,    2,    5,    6,    3,    6,    2],
#         [   2, 5455,    6,    7,    2,    8,    8],
#         [   1,    2,    3,    4,    5,    6,    7]],
#
#        [[   1,    2,    5,    6,    3,    6,    2],
#         [   2, 5455,    6,    7,    2,    8,    8],
#         [   1,    2,    3,    4,    5,    6,    7]]])

# %%
np.ndim(arr3
       )
# Out:
# 3

# %%
arr4 = np.array([[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
])

# %%
arr4
# Out:
# array([[[[   1,    2,    5,    6,    3,    6,    2],
#          [   2, 5455,    6,    7,    2,    8,    8],
#          [   1,    2,    3,    4,    5,    6,    7]],
#
#         [[   1,    2,    5,    6,    3,    6,    2],
#          [   2, 5455,    6,    7,    2,    8,    8],
#          [   1,    2,    3,    4,    5,    6,    7]],
#
#         [[   1,    2,    5,    6,    3,    6,    2],
#          [   2, 5455,    6,    7,    2,    8,    8],
#          [   1,    2,    3,    4,    5,    6,    7]]],
#
#
#        [[[   1,    2,    5,    6,    3,    6,    2],
#          [   2, 5455,    6,    7,    2,    8,    8],
#          [   1,    2,    3,    4,    5,    6,    7]],
#
#         [[   1,    2,    5,    6,    3,    6,    2],
#          [   2, 5455,    6,    7,    2,    8,    8],
#          [   1,    2,    3,    4,    5,    6,    7]],
#
#         [[   1,    2,    5,    6,    3,    6,    2],
#          [   2, 5455,    6,    7,    2,    8,    8],
# ...

# %%
arr4.shape
# Out:
# (3, 3, 3, 7)

# %%
arr4.ndim
# Out:
# 4

# %%
arr5 = np.array([[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]])

# %%
arr5
# Out:
# array([[[[[   1,    2,    5,    6,    3,    6,    2],
#           [   2, 5455,    6,    7,    2,    8,    8],
#           [   1,    2,    3,    4,    5,    6,    7]],
#
#          [[   1,    2,    5,    6,    3,    6,    2],
#           [   2, 5455,    6,    7,    2,    8,    8],
#           [   1,    2,    3,    4,    5,    6,    7]],
#
#          [[   1,    2,    5,    6,    3,    6,    2],
#           [   2, 5455,    6,    7,    2,    8,    8],
#           [   1,    2,    3,    4,    5,    6,    7]]],
#
#
#         [[[   1,    2,    5,    6,    3,    6,    2],
#           [   2, 5455,    6,    7,    2,    8,    8],
#           [   1,    2,    3,    4,    5,    6,    7]],
#
#          [[   1,    2,    5,    6,    3,    6,    2],
#           [   2, 5455,    6,    7,    2,    8,    8],
#           [   1,    2,    3,    4,    5,    6,    7]],
#
#          [[   1,    2,    5,    6,    3,    6,    2],
#           [   2, 5455,    6,    7,    2,    8,    8],
# ...

# %%
arr5.shape
# Out:
# (3, 3, 3, 3, 7)

# %%
arr5.ndim
# Out:
# 5

# %%
arr6 = np.array([[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]])

# %%
arr6.shape
# Out:
# (3, 3, 3, 3, 3, 7)

# %%
arr6.ndim
# Out:
# 6

# %%
arr7 = np.array([[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
],[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
],[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
]])

# %%
arr7
# Out:
# array([[[[[[[[   1,    2,    5, ...,    3,    6,    2],
#              [   2, 5455,    6, ...,    2,    8,    8],
#              [   1,    2,    3, ...,    5,    6,    7]],
#
#             [[   1,    2,    5, ...,    3,    6,    2],
#              [   2, 5455,    6, ...,    2,    8,    8],
#              [   1,    2,    3, ...,    5,    6,    7]],
#
#             [[   1,    2,    5, ...,    3,    6,    2],
#              [   2, 5455,    6, ...,    2,    8,    8],
#              [   1,    2,    3, ...,    5,    6,    7]]],
#
#
#            [[[   1,    2,    5, ...,    3,    6,    2],
#              [   2, 5455,    6, ...,    2,    8,    8],
#              [   1,    2,    3, ...,    5,    6,    7]],
#
#             [[   1,    2,    5, ...,    3,    6,    2],
#              [   2, 5455,    6, ...,    2,    8,    8],
#              [   1,    2,    3, ...,    5,    6,    7]],
#
#             [[   1,    2,    5, ...,    3,    6,    2],
# ...

# %%
arr7.shape
# Out:
# (3, 3, 3, 3, 3, 3, 3, 7)

# %%
arr8 = np.array([[[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
],[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
],[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
]],[[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
],[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
],[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
]],[[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
],[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
],[
    [[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]],[[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]],
[[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
],
[[
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


],
    [
    
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ],
    [
        [1,2,5,6,3,6,2],
        [2,5455,6,7,2,8,8],
        [1,2,3,4,5,6,7]
        
    ]


]
]]]
    
]]])

# %%
arr8
# Out:
# array([[[[[[[[[   1,    2,    5, ...,    3,    6,    2],
#               [   2, 5455,    6, ...,    2,    8,    8],
#               [   1,    2,    3, ...,    5,    6,    7]],
#
#              [[   1,    2,    5, ...,    3,    6,    2],
#               [   2, 5455,    6, ...,    2,    8,    8],
#               [   1,    2,    3, ...,    5,    6,    7]],
#
#              [[   1,    2,    5, ...,    3,    6,    2],
#               [   2, 5455,    6, ...,    2,    8,    8],
#               [   1,    2,    3, ...,    5,    6,    7]]],
#
#
#             [[[   1,    2,    5, ...,    3,    6,    2],
#               [   2, 5455,    6, ...,    2,    8,    8],
#               [   1,    2,    3, ...,    5,    6,    7]],
#
#              [[   1,    2,    5, ...,    3,    6,    2],
#               [   2, 5455,    6, ...,    2,    8,    8],
#               [   1,    2,    3, ...,    5,    6,    7]],
#
#              [[   1,    2,    5, ...,    3,    6,    2],
# ...

# %%
arr8.shape
# Out:
# (3, 3, 3, 3, 3, 3, 3, 3, 7)
